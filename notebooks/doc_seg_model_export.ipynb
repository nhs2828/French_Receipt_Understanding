# %%
from pathlib import Path
from ultralytics import YOLO

# %%
ROOT_DIR = Path.cwd().parent

# %%
model = YOLO(ROOT_DIR /"local_models/doc_seg/new/best.pt")
# The model is YOLO26 so it has NMS free end-to-end-prediction (overrides with end2end=False to use NMS)
# enable nms, overrides NMS free pipeline with end2end=False
model.export(
    format="onnx", 
    end2end=False, 
    nms=True)
# Out:
# Ultralytics 8.4.102 🚀 Python-3.11.15 torch-2.13.0 CPU (Apple M1 Pro)
# YOLO26n-seg summary (fused): 175 layers, 3,042,695 parameters, 0 gradients, 9.0 GFLOPs
#
# PyTorch: starting from '/Users/son/Documents/my_ORC/Receipt_Understanding/local_models/doc_seg/new/best.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) ((1, 300, 38), (1, 32, 160, 160)) (6.2 MB)
#
# ONNX: starting export with onnx 1.22.0 opset 20...
# ONNX: slimming with onnxslim 0.1.95...
# ONNX: export success ✅ 2.1s, saved as '/Users/son/Documents/my_ORC/Receipt_Understanding/local_models/doc_seg/new/best.onnx' (10.6 MB)
#
# Export complete (2.6s)
# Results saved to /Users/son/Documents/my_ORC/Receipt_Understanding/local_models/doc_seg/new/best.onnx
# Predict:         yolo predict task=segment model=/Users/son/Documents/my_ORC/Receipt_Understanding/local_models/doc_seg/new/best.onnx imgsz=640
# Validate:        yolo val task=segment model=/Users/son/Documents/my_ORC/Receipt_Understanding/local_models/doc_seg/new/best.onnx imgsz=640 data=data.yaml
# Visualize:       https://netron.app
# '/Users/son/Documents/my_ORC/Receipt_Understanding/local_models/doc_seg/new/best.onnx'
